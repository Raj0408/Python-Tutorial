# %%
from sqlite3 import Row
from tkinter import *
import tkinter as tk
from tkinter import messagebox
import pandas as pd
DF = pd.DataFrame()
window = tk.Tk()
window.title("Diabetes Predication")

# preg plas pres skin test mass predi age

BG_GRAY = "#ABB2B9"
BG_COLOR = "#17202A"
TEXT_COLOR = "#EAECEE"
BG_BLACK = "#000000"
BG_WHITE = "#FFFFFF"

FONT = "Helvetica 14"
FONT_BOLD = "Helvetica 13 bold"

title = tk.Label(text="Preg",padx=20,pady=20,font=FONT_BOLD)
title.grid(row=1,column=1)

text_feild = tk.Text(height=1,width=45,)
text_feild.grid(row=1,column=2)


title2 = tk.Label(text="plas",padx=20,pady=20,font=FONT_BOLD)
title2.grid(row=2,column=1)

text_feild2 = tk.Text(height=1,width=45)
text_feild2.grid(row=2,column=2)

title3 = tk.Label(text="pres",padx=20,pady=20,font=FONT_BOLD)
title3.grid(row=3,column=1)

text_feild2 = tk.Text(height=1,width=45)
text_feild2.grid(row=3,column=2)


title4 = tk.Label(text="skin",padx=20,pady=20,font=FONT_BOLD)
title4.grid(row=4,column=1)

text_feild4 = tk.Text(height=1,width=45)
text_feild4.grid(row=4,column=2)

title5 = tk.Label(text="test",padx=20,pady=20,font=FONT_BOLD)
title5.grid(row=5,column=1)

text_feild5 = tk.Text(height=1,width=45)
text_feild5.grid(row=5,column=2)

title6 = tk.Label(text="mas",padx=20,pady=20,font=FONT_BOLD)
title6.grid(row=6,column=1)

text_feild6 = tk.Text(height=1,width=45)
text_feild6.grid(row=6,column=2)

title7 = tk.Label(text="predi",padx=20,pady=20,font=FONT_BOLD)
title7.grid(row=7,column=1)

text_feild7 = tk.Text(height=1,width=45)
text_feild7.grid(row=7,column=2)

title8 = tk.Label(text="age",padx=20,pady=20,font=FONT_BOLD)
title8.grid(row=8,column=1)

text_feild8 = tk.Text(height=1,width=45)
text_feild8.grid(row=8,column=2)

def submit():
    print('Submited')

def transfrom():
    print('transfrom')
    print(text_feild8.get("1.0",END))


submit = tk.Button(text="Submit",command=submit).grid(row=9,column=6)
Transform = tk.Button(text="Transform",command=transfrom).grid(row=9,column=7)





# txt = Text(background=BG_BLACK,foreground=TEXT_COLOR,font=FONT,height=10,width=20)
# txt.place(anchor='n', relx=0.19, rely=0)
# txt.config(state=DISABLED)
# def send():
#     txt.config(state=NORMAL)
#     txt.insert(END,"You -> ", text_feild.get("1.0",END),"\n")
#     text_feild.delete("1.0",END)
#     txt.config(state=DISABLED)

# # txt = Text(window, bg=BG_COLOR, fg=TEXT_COLOR, font=FONT, width=60).pack()

# send_button = tk.Button(frame,text="Send",background=BG_GRAY,foreground=TEXT_COLOR,font=FONT_BOLD,height=1,command=send)
# send_button.pack()
# send_button.place(anchor='se', relx=1, rely=1)

tk.mainloop()
# Out:
# transfrom
# 18

# %%
import pandas as pd
DF = pd.DataFrame()
def action():
    global DB
    import pandas as pd
    DF = pd.DataFrame(columns=['Preg','Plas','Pres','skin','test','mass','pedi','age'])
    PREG=text_feild.get()
    text_feild.get()
    print(PREG)
    DF.loc[0,'Preg']=PREG
    PLAS=text_feild2.get()
    DF.loc[0,'Plas']=PLAS
    PRES=text_feild4.get()
    DF.loc[0,'Pres']=PRES
    SKIN=skin_var.get()
    DF.loc[0,'skin']=SKIN
    TEST=test_var.get()
    DF.loc[0,'test']=TEST
    MASS=mass_var.get()
    DF.loc[0,'mass']=MASS
    PEDI=pedi_var.get()
    DF.loc[0,'pedi']=PEDI
    AGE=age_var.get()
    DF.loc[0,'age']=AGE
    print(DF.shape)
    print(DF)
    print(type(DF))
    print(type(DF["Preg"][0]))
    DB=DF

# %%
def Output():
    print(DB["Preg"])
    DB["Preg"] = pd.to_numeric(DB["Preg"])
    DB["Plas"] = pd.to_numeric(DB["Plas"])
    DB["Pres"] = pd.to_numeric(DB["Pres"])
    DB["skin"] = pd.to_numeric(DB["skin"])
    DB["test"] = pd.to_numeric(DB["test"])
    DB["mass"] = pd.to_numeric(DB["mass"])
    DB["pedi"] = pd.to_numeric(DB["pedi"])
    DB["age"] = pd.to_numeric(DB["age"])
    print(DB)
